# %% [markdown]
# https://console.groq.com/docs/text-to-speech

# %%
pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 3.3 MB/s eta 0:00:00
# ...

# %%
import os
import getpass

# %%
os.environ["GROQ_API_KEY"] = getpass.getpass()
# Out:
# ··········

# %%
import os
from groq import Groq

client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

speech_file_path = "speech.wav"
model = "canopylabs/orpheus-v1-english"
voice = "troy"
text = "I love building LLM applications with GROQ API!"
response_format = "wav"

response = client.audio.speech.create(
    model=model,
    voice=voice,
    input=text,
    response_format=response_format
)

response.write_to_file(speech_file_path)

# %%
speech_file_path = "Prompt.wav"
model = "canopylabs/orpheus-v1-english"
voice = "troy"
text = """Prompt engineering is a relatively new discipline for developing and optimizing prompts to efficiently use language models (LMs) for a wide variety of applications and research topics.
Prompt engineering skills help to better understand the capabilities and limitations of large language models (LLMs).!"""
response_format = "wav"

response = client.audio.speech.create(
    model=model,
    voice=voice,
    input=text,
    response_format=response_format
)

response.write_to_file(speech_file_path)

# %% [markdown]
# Speech to Text

# %%
import os
import json
from groq import Groq

# Initialize the Groq client
client = Groq()

# Specify the path to the audio file
# filename = os.path.dirname(__file__) + "/content/speech.wav" # Replace with your audio file!
# Correct path handling
filename = os.path.join(os.getcwd(), "speech.wav")

# Open the audio file
with open(filename, "rb") as file:
    # Create a transcription of the audio file
    transcription = client.audio.transcriptions.create(
      file=file, # Required audio file
      model="whisper-large-v3-turbo", # Required model to use for transcription
      prompt="Specify context or spelling",  # Optional
      response_format="verbose_json",  # Optional
      timestamp_granularities = ["word", "segment"], # Optional (must set response_format to "json" to use and can specify "word", "segment" (default), or both)
      language="en",  # Optional
      temperature=0.0  # Optional
    )
    # To print only the transcription text, you'd use print(transcription.text) (here we're printing the entire transcription object to access timestamps)
    print(json.dumps(transcription, indent=2, default=str))
# Out:
# "Transcription(text=' I love building LLM applications with Grok API', task='transcribe', language='English', duration=4.47, words=[{'word': 'I', 'start': 0.3, 'end': 0.44}, {'word': 'love', 'start': 0.44, 'end': 1}, {'word': 'building', 'start': 1, 'end': 1.54}, {'word': 'LLM', 'start': 1.54, 'end': 2.22}, {'word': 'applications', 'start': 2.22, 'end': 2.82}, {'word': 'with', 'start': 2.82, 'end': 3.22}, {'word': 'Grok', 'start': 3.22, 'end': 3.62}, {'word': 'API', 'start': 3.62, 'end': 4.08}], segments=[{'id': 0, 'seek': 0, 'start': 0, 'end': 4.48, 'text': ' I love building LLM applications with Grok API', 'tokens': [50365, 286, 959, 2390, 441, 43, 44, 5821, 365, 12981, 74, 9362, 50589], 'temperature': 0, 'avg_logprob': -0.12800495, 'compression_ratio': 0.8518519, 'no_speech_prob': 1.52944e-12}], x_groq={'id': 'req_01kq2sj7w1ey9bkrcejcdrctyz'})"

# %%
import os
import json
from groq import Groq

# Initialize the Groq client
client = Groq()

# Specify the path to the audio file
# filename = os.path.dirname(__file__) + "/content/speech.wav" # Replace with your audio file!
# Correct path handling
filename = os.path.join(os.getcwd(), "/content/Prompt.wav")

# Open the audio file
with open(filename, "rb") as file:
    # Create a transcription of the audio file
    transcription = client.audio.transcriptions.create(
      file=file, # Required audio file
      model="whisper-large-v3-turbo", # Required model to use for transcription
      prompt="Specify context or spelling",  # Optional
      response_format="verbose_json",  # Optional
      timestamp_granularities = ["word", "segment"], # Optional (must set response_format to "json" to use and can specify "word", "segment" (default), or both)
      language="en",  # Optional
      temperature=0.0  # Optional
    )
    # To print only the transcription text, you'd use print(transcription.text) (here we're printing the entire transcription object to access timestamps)
    print(json.dumps(transcription, indent=2, default=str))
# Out:
# "Transcription(text=' Prompt engineering is a relatively new discipline for developing and optimizing prompts to efficiently use language models for a wide variety of applications and research topics. Prompt engineering skills help to better understand the capabilities and limitations of large language models .', task='transcribe', language='English', duration=17.91, words=[{'word': 'Prompt', 'start': 0, 'end': 0.32}, {'word': 'engineering', 'start': 0.32, 'end': 0.68}, {'word': 'is', 'start': 0.68, 'end': 1.04}, {'word': 'a', 'start': 1.04, 'end': 1.2}, {'word': 'relatively', 'start': 1.2, 'end': 1.72}, {'word': 'new', 'start': 1.72, 'end': 2.14}, {'word': 'discipline', 'start': 2.14, 'end': 2.62}, {'word': 'for', 'start': 2.62, 'end': 2.9}, {'word': 'developing', 'start': 2.9, 'end': 3.5}, {'word': 'and', 'start': 3.5, 'end': 3.74}, {'word': 'optimizing', 'start': 3.74, 'end': 4.26}, {'word': 'prompts', 'start': 4.26, 'end': 4.82}, {'word': 'to', 'start': 4.82, 'end': 5.12}, {'word
# ...
